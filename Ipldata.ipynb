# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
deliveries=pd.read_csv("deliveries.csv")

# %%
matches=pd.read_csv("matches.csv")

# %%
matches['season'].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#       dtype=int64)

# %%
id_counts=matches['season'].value_counts() #no. of matches in each season

# %%
id_counts #no. of matches in each season
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
matches.iloc[matches['win_by_runs'].idxmax()]   #win by most runs
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
m=matches[(matches.season==2017)]       #win by most runs in 2017

# %%
m.iloc[m['win_by_runs'].idxmax()]       #win by most runs in 2017
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
matches.iloc[matches['win_by_wickets'].idxmax()]     #win by most no. of wickets
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %%
 matches.iloc[matches['win_by_wickets'].idxmax()] ['winner'] #win by most no. of wickets
# Out:
# 'Kolkata Knight Riders'

# %%
m.iloc[m['win_by_wickets'].idxmax()]                          #win by most no. of wickets in 2017
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %%
matches.iloc[matches[matches['win_by_runs'].ge(1)].win_by_runs.idxmin()]   #win by minimum runs
# Out:
# id                                                        59
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-05-21
# team1                                         Mumbai Indians
# team2                                 Rising Pune Supergiant
# toss_winner                                   Mumbai Indians
# toss_decision                                            bat
# result                                                normal
# dl_applied                                                 0
# winner                                        Mumbai Indians
# win_by_runs                                                1
# win_by_wickets                                             0
# player_of_match                                    KH Pandya
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
m.iloc[m[m['win_by_runs'].ge(1)].win_by_runs.idxmin()]   #win by minimum runs in 2017
# Out:
# id                                                        59
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-05-21
# team1                                         Mumbai Indians
# team2                                 Rising Pune Supergiant
# toss_winner                                   Mumbai Indians
# toss_decision                                            bat
# result                                                normal
# dl_applied                                                 0
# winner                                        Mumbai Indians
# win_by_runs                                                1
# win_by_wickets                                             0
# player_of_match                                    KH Pandya
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
matches.iloc[matches[matches['win_by_wickets'].ge(1)].win_by_wickets.idxmin()]   #win by minimum runs
# Out:
# id                                   560
# season                              2015
# city                             Kolkata
# date                          2015-05-09
# team1                    Kings XI Punjab
# team2              Kolkata Knight Riders
# toss_winner              Kings XI Punjab
# toss_decision                        bat
# result                            normal
# dl_applied                             0
# winner             Kolkata Knight Riders
# win_by_runs                            0
# win_by_wickets                         1
# player_of_match               AD Russell
# venue                       Eden Gardens
# umpire1                     AK Chaudhary
# umpire2                  HDPK Dharmasena
# umpire3                              NaN
# Name: 559, dtype: object

# %%
m.iloc[m[m['win_by_wickets'].ge(1)].win_by_wickets.idxmin()]   #win by minimum wicke in 2017
# Out:
# id                               49
# season                         2017
# city                         Kanpur
# date                     2017-05-10
# team1                 Gujarat Lions
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner             Delhi Daredevils
# win_by_runs                       0
# win_by_wickets                    2
# player_of_match             SS Iyer
# venue                    Green Park
# umpire1                    YC Barde
# umpire2                AK Chaudhary
# umpire3                         NaN
# Name: 48, dtype: object

# %%
sns.countplot(x='season',data=matches)              #which season has most no. of matches

# %%
data=matches.city.value_counts()                               #which City is most Popular in IPL
sns.set(style="whitegrid")
fig,ax=plt.subplots(figsize=(10,8))
sns.barplot(y=data.index,x=data,orient='h')

# %%
data=matches.winner.value_counts()                               #which team is most Popular in IPL
fig,ax=plt.subplots(figsize=(10,5))
sns.barplot(y=data.index,x=data,orient='h')

# %%
fig,ax=plt.subplots(figsize=(10,5))                          #Team winning stats in 2017
sns.countplot(y='winner',data=m)

# %%
m1=matches[(matches.season==2016)] 
fig,ax=plt.subplots(figsize=(10,5))                          #Team winning stats in 2016
sns.countplot(y='winner',data=m1)

# %%
m2=matches[(matches.season==2015)]
fig,ax=plt.subplots(figsize=(10,5))                          #Team winning stats in 2015
sns.countplot(y='winner',data=m2)

# %%
m3=matches[(matches.season==2014)] 
fig,ax=plt.subplots(figsize=(10,5))                          #Team winning stats in 2014
sns.countplot(y='winner',data=m3)

# %%
m4=matches[(matches.season==2013)] 
fig,ax=plt.subplots(figsize=(10,5))                          #Team winning stats in 2013
sns.countplot(y='winner',data=m4)

# %%
m5=matches[(matches.season==2012)] 
fig,ax=plt.subplots(figsize=(10,5))                          #Team winning stats in 2012
sns.countplot(y='winner',data=m5)

# %%
m6=matches[(matches.season==2011)] 
fig,ax=plt.subplots(figsize=(10,5))                          #Team winning stats in 2011
sns.countplot(y='winner',data=m6)

# %%
m7=matches[(matches.season==2010)] 
fig,ax=plt.subplots(figsize=(10,5))                          #Team winning stats in 2010
sns.countplot(y='winner',data=m7)

# %%
m8=matches[(matches.season==2009)] 
fig,ax=plt.subplots(figsize=(10,5))                          #Team winning stats in 2009
sns.countplot(y='winner',data=m8)

# %%
m9=matches[(matches.season==2008)] 
fig,ax=plt.subplots(figsize=(10,5))                          #Team winning stats in 2008
sns.countplot(y='winner',data=m9)

# %%
data=matches.winner.value_counts()                               # Highest Win % Market Share in IPL
sns.set(style="whitegrid")
fig,ax=plt.subplots(figsize=(10,8))
sns.barplot(y=data.index,x=data,orient='h')

# %%
top_players=matches.player_of_match.value_counts()[:10]      #Top player of the match Winners

# %%
top_players
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# SK Raina          14
# RG Sharma         14
# MS Dhoni          13
# G Gambhir         13
# AM Rahane         12
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
top_players1=m.player_of_match.value_counts()[:10]          #Top player of the match Winners in 2017

# %%
top_players2=m1.player_of_match.value_counts()[:10]         #Top player of the match Winners in 2016

# %%
top_players1
# Out:
# BA Stokes          3
# NM Coulter-Nile    3
# N Rana             2
# SP Narine          2
# JD Unadkat         2
# RV Uthappa         2
# Rashid Khan        2
# AJ Tye             2
# KH Pandya          2
# Sandeep Sharma     2
# Name: player_of_match, dtype: int64

# %%
top_players2
# Out:
# V Kohli           5
# RG Sharma         4
# AB de Villiers    4
# AD Russell        3
# AJ Finch          3
# DA Warner         3
# CH Morris         2
# MP Stoinis        2
# KH Pandya         2
# YK Pathan         2
# Name: player_of_match, dtype: int64

# %%
top_players.plot.bar()
sns.barplot(x=top_players.index,y=top_players,orient='v')              #Top player of the match Winners
palette="Blues"
plt.show()

# %%
matches['player_of_match'].value_counts().head(15).plot(kind='pie',figsize=(8,8))
                                                              #pie chart for top 15 player of the match

# %%
matches['winner'].value_counts().plot(kind='bar',figsize=(15,4))
                                                   #bar graph for no. of times a team was the winner of the match

# %%
ss=matches['toss_winner']==matches['winner']                 #Does Winning the Toss helps in Winning matches?
ss.groupby(ss).size()
# Out:
# False    311
# True     325
# dtype: int64

# %%
sns.countplot(ss)                                            #Does Winning the Toss helps in Winning matches?
                                                             #True=win   , False=lose

# %%
ss=matches['winner']==matches['toss_winner']                 #Match Winner is Toss Winner - Overall
ss.groupby(ss).size()
# Out:
# False    311
# True     325
# dtype: int64

# %%
ss=matches['toss_winner']==matches['winner']                 #Did Choosing to Bat first or Field First helped in Toss winning
ss.groupby(ss).size()
# Out:
# False    311
# True     325
# dtype: int64

# %%
ss=m['winner']==m['toss_winner']                           #Analysing Impact of Toss Winning team Season 2017
ss.groupby(ss).size()
# Out:
# False    25
# True     34
# dtype: int64

# %%
sns.countplot(ss)                                        #Analysing Impact of Toss Winning team Season 2017
                                                         #True=win   , False=lose

# %%
ss=m1['winner']==m1['toss_winner']                           #Analysing Impact of Toss Winning team Season 2016
ss.groupby(ss).size()
# Out:
# False    26
# True     34
# dtype: int64

# %%
sns.countplot(ss)                     #Analysing Impact of Toss Winning team Season 2016
                                      #True=win   , False=lose

# %%
ss=m2['winner']==m2['toss_winner']                           #Analysing Impact of Toss Winning team Season 2015
ss.groupby(ss).size()
# Out:
# False    31
# True     28
# dtype: int64

# %%
sns.countplot(ss)                                 #Analysing Impact of Toss Winning team Season 2015
                                                 #True=win   , False=lose

# %%
ss=m3['winner']==m3['toss_winner']                           #Analysing Impact of Toss Winning team Season 2014
ss.groupby(ss).size()
# Out:
# False    30
# True     30
# dtype: int64

# %%
sns.countplot(ss)                                 #Analysing Impact of Toss Winning team Season 2014
                                                 #True=win   , False=lose

# %%
ss=m4['winner']==m4['toss_winner']                           #Analysing Impact of Toss Winning team Season 2013
ss.groupby(ss).size()
# Out:
# False    40
# True     36
# dtype: int64

# %%
sns.countplot(ss)                                 #Analysing Impact of Toss Winning team Season 2013
                                                 #True=win   , False=lose

# %%
ss=m5['winner']==m5['toss_winner']                           #Analysing Impact of Toss Winning team Season 2012
ss.groupby(ss).size()
# Out:
# False    41
# True     33
# dtype: int64

# %%
sns.countplot(ss)                                 #Analysing Impact of Toss Winning team Season 2012
                                                 #True=win   , False=lose

# %%
ss=m6['winner']==m6['toss_winner']                           #Analysing Impact of Toss Winning team Season 2011
ss.groupby(ss).size()
# Out:
# False    35
# True     38
# dtype: int64

# %%
sns.countplot(ss)                                 #Analysing Impact of Toss Winning team Season 2011
                                                 #True=win   , False=lose

# %%
ss=m7['winner']==m7['toss_winner']                           #Analysing Impact of Toss Winning team Season 2010
ss.groupby(ss).size()
# Out:
# False    29
# True     31
# dtype: int64

# %%
sns.countplot(ss)                                 #Analysing Impact of Toss Winning team Season 2010
                                                 #True=win   , False=lose

# %%
ss=m8['winner']==m8['toss_winner']                           #Analysing Impact of Toss Winning team Season 2009
ss.groupby(ss).size()
# Out:
# False    24
# True     33
# dtype: int64

# %%
sns.countplot(ss)                                 #Analysing Impact of Toss Winning team Season 2009
                                                 #True=win   , False=lose

# %%
ss=m9['winner']==m9['toss_winner']                           #Analysing Impact of Toss Winning team Season 2008
ss.groupby(ss).size()
# Out:
# False    30
# True     28
# dtype: int64

# %%
sns.countplot(ss)                                            #Analysing Impact of Toss Winning team Season 2008
                                                             #True=win   , False=lose

# %%
trusted_umpire=matches.umpire1.value_counts()[:10]

# %%
trusted_umpire                                  #Who is Most Trusted Umpire in IPL 1
# Out:
# HDPK Dharmasena    73
# Asad Rauf          51
# AK Chaudhary       43
# Aleem Dar          38
# BF Bowden          37
# S Ravi             36
# BR Doctrove        34
# M Erasmus          32
# RE Koertzen        20
# S Asnani           19
# Name: umpire1, dtype: int64

# %%
trusted_umpire.plot.bar()
sns.barplot(x=trusted_umpire .index,y=trusted_umpire ,orient='v')              #Who is Most Trusted Umpire in IPL 1
palette="Blues"
plt.show()

# %%
trusted_umpire1=matches.umpire2.value_counts()[:10]

# %%
trusted_umpire1                                    #Who is Most Trusted Umpire in IPL 2
# Out:
# SJA Taufel       54
# C Shamshuddin    50
# S Ravi           49
# RJ Tucker        38
# CK Nandan        36
# RB Tiffin        30
# VA Kulkarni      28
# SK Tarapore      26
# BNJ Oxenford     25
# AM Saheba        23
# Name: umpire2, dtype: int64

# %%
trusted_umpire1.plot.bar()
sns.barplot(x=trusted_umpire1.index,y=trusted_umpire1,orient='v')              #Who is Most Trusted Umpire in IPL 2
palette="Blues"
plt.show()

# %%
u1=matches['umpire1'] 
l1=list(u1)
u2=matches['umpire2']
l2=list(u2)
l=l1+l2
s=max(l,key=l.count)
num=l.count(s)
print(s,num)
# Out:
# HDPK Dharmasena 87

# %%
weather=matches[matches.dl_applied==1]

# %%
cont=weather.venue.value_counts()

# %%
cont
# Out:
# Eden Gardens                                           3
# M Chinnaswamy Stadium                                  3
# Rajiv Gandhi International Stadium, Uppal              2
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    2
# Feroz Shah Kotla                                       2
# Newlands                                               1
# SuperSport Park                                        1
# Kingsmead                                              1
# Nehru Stadium                                          1
# Name: venue, dtype: int64

# %%
sns.set(style="whitegrid")                                    #Which Venue did Weather Affected Most
fig,ax=plt.subplots(figsize=(6,3))
sns.barplot(y=cont.index,x=cont,orient='h')

# %%
tw=matches[matches.toss_decision=='field']

# %%
ts=tw[tw['toss_winner']==tw['winner']]['venue'].value_counts()               #Best Stadium to Chase and Win

# %%
ts
# Out:
# M Chinnaswamy Stadium                                   32
# Eden Gardens                                            22
# Feroz Shah Kotla                                        19
# Wankhede Stadium                                        17
# Rajiv Gandhi International Stadium, Uppal               12
# Sawai Mansingh Stadium                                  12
# Punjab Cricket Association Stadium, Mohali              11
# Maharashtra Cricket Association Stadium                  9
# Dr DY Patil Sports Academy                               6
# SuperSport Park                                          5
# MA Chidambaram Stadium, Chepauk                          4
# Green Park                                               4
# Punjab Cricket Association IS Bindra Stadium, Mohali     4
# Holkar Cricket Stadium                                   4
# Himachal Pradesh Cricket Association Stadium             4
# Saurashtra Cricket Association Stadium                   4
# ...

# %%
sns.set(style="whitegrid")                                                  #Best Stadium to Chase and Win
fig,ax=plt.subplots(figsize=(10,10))
sns.barplot(y=ts.index,x=ts,orient='h')

# %%
venue1=matches[matches.venue=='M Chinnaswamy Stadium']                            #Best Team in Best Chasing Venue

# %%
bst=venue1[tw['toss_winner']==tw['winner']]['winner'].value_counts()                   #Best Team in Best Chasing Venue
# Out:
# C:\Users\Kanhaiya Sinha\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-80-04fb8d6916d0> in <module>
# ----> 1 bst=venue1[tw['toss_winner']==tw['winner']]['winner'].value_counts()                   #Best Team in Best Chasing Venue
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2916         # Do we have a (boolean) 1d indexer?
#    2917         if com.is_bool_indexer(key):
# -> 2918             return self._getitem_bool_array(key)
#    2919
#    2920         # We are left with two options: a single key, and a collection of keys,
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
# ...

# %%
bst                                                                                  #Best Team in Best Chasing Venue

# %%
bst.plot.bar()
sns.barplot(x=bst.index,y=bst,orient='v')                          #Best Team in Best Chasing Venue(M Chinnaswamy Stadium)
palette="Blues"
plt.show()

# %%
tw1=matches[matches.toss_decision=='bat']    
tw1#Best Stadium to Bat first and Win

# %%
ts1=tw1[tw1['toss_winner']==tw1['winner']]['venue'].value_counts()           #Best Stadium to Bat first and Win

# %%
ts1

# %%
ve=matches[matches.venue=='MA Chidambaram Stadium, Chepauk'] 
ve                                                                 #Best Team in Best Defending Venue

# %%
bst=ve[tw1['toss_winner']==tw1['winner']]['winner'].value_counts()  #Best Team in defending Venue

# %%
ts1=tw[tw['toss_winner']==tw['winner']]['winner'].value_counts()               #Best Stadium to Chasing                                   #Which Team is Best in Defending

# %%
ts1

# %%
ts2=tw1[tw1['toss_winner']==tw1['winner']]['winner'].value_counts()          #Best Stadium to Defending

# %%
ts2                                                                          #Best Stadium to Defending
